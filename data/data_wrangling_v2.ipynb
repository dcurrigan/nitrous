# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Metro Data

# %%
metro_df = pd.read_csv("data_2022.csv")
metro_df
# Out:
#           date                                     name     cylinder  units
# 0    1/01/2022                         Bentley Hospital   cylinder_g      2
# 1    1/01/2022  King Edward Memorial Hospital For Women   cylinder_g      8
# 2    1/01/2022     Armadale-Kelmscott Memorial Hospital   cylinder_c      1
# 3    1/01/2022              Rockingham General Hospital   cylinder_c      1
# 4    1/01/2022                     Royal Perth Hospital  cylinder_f8      1
# ..         ...                                      ...          ...    ...
# 96   1/11/2022                          Albany Hospital   cylinder_g      2
# 97   1/11/2022                          Warren Hospital   cylinder_g      2
# 98   1/12/2022                          Albany Hospital   cylinder_g      2
# 99   1/12/2022                          Warren Hospital   cylinder_g      2
# 100  1/12/2022                       Geraldton Hospital   cylinder_g      2
#
# [101 rows x 4 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

metro_df = pd.read_csv("/content/drive/MyDrive/Data Analytics/Practice/Nitrous DB/nitrous/data/metro_clean.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
metro_df.rename(columns={"hospital":"name"}, inplace=True)
metro_df
# Out:
#           date                                     name     cylinder  units
# 0    1/01/2022                         Bentley Hospital   cylinder_g      2
# 1    1/01/2022  King Edward Memorial Hospital For Women   cylinder_g      8
# 2    1/01/2022     Armadale-Kelmscott Memorial Hospital   cylinder_c      1
# 3    1/01/2022              Rockingham General Hospital   cylinder_c      1
# 4    1/01/2022                     Royal Perth Hospital  cylinder_f8      1
# ..         ...                                      ...          ...    ...
# 96   1/11/2022                          Albany Hospital   cylinder_g      2
# 97   1/11/2022                          Warren Hospital   cylinder_g      2
# 98   1/12/2022                          Albany Hospital   cylinder_g      2
# 99   1/12/2022                          Warren Hospital   cylinder_g      2
# 100  1/12/2022                       Geraldton Hospital   cylinder_g      2
#
# [101 rows x 4 columns]

# %%
metro_df['name'].unique()
# Out:
# array(['Armadale-Kelmscott Memorial Hospital', 'Bentley Hospital',
#        'Fiona Stanley Hospital', 'Kalamunda District Community Hospital',
#        'Osborne Park Hospital', 'Rockingham General Hospital',
#        'Sir Charles Gairdner Hospital',
#        'King Edward Memorial Hospital For Women', 'Royal Perth Hospital',
#        "Perth Children's Hospital", 'METRO HEALTH SERVICE BOARD'],
#       dtype=object)

# %%
metro_df = metro_df[metro_df['name'] != 'METRO HEALTH SERVICE BOARD']
metro_df
# Out:
#           date                                   name     cylinder  units
# 0    1/01/2017   Armadale-Kelmscott Memorial Hospital  cylinder_f8      1
# 1    1/01/2017                       Bentley Hospital   cylinder_e      2
# 2    1/01/2017                 Fiona Stanley Hospital  cylinder_f8      2
# 3    1/01/2017  Kalamunda District Community Hospital   cylinder_e      2
# 4    1/01/2017                  Osborne Park Hospital   cylinder_g      4
# ..         ...                                    ...          ...    ...
# 301  1/11/2021                  Osborne Park Hospital   cylinder_g      4
# 302  1/11/2021          Sir Charles Gairdner Hospital   cylinder_c      1
# 303  1/12/2021                 Fiona Stanley Hospital  cylinder_f8      1
# 304  1/12/2021                  Osborne Park Hospital   cylinder_g      2
# 305  1/12/2021            Rockingham General Hospital  cylinder_f8      1
#
# [283 rows x 4 columns]

# %%
metro_df[['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 
          'cylinder_g', 'total']] = ["", "", "", "", "", "", ""]
metro_df
# Out:
#           date                                     name     cylinder  units  \
# 0    1/01/2022                         Bentley Hospital   cylinder_g      2
# 1    1/01/2022  King Edward Memorial Hospital For Women   cylinder_g      8
# 2    1/01/2022     Armadale-Kelmscott Memorial Hospital   cylinder_c      1
# 3    1/01/2022              Rockingham General Hospital   cylinder_c      1
# 4    1/01/2022                     Royal Perth Hospital  cylinder_f8      1
# ..         ...                                      ...          ...    ...
# 96   1/11/2022                          Albany Hospital   cylinder_g      2
# 97   1/11/2022                          Warren Hospital   cylinder_g      2
# 98   1/12/2022                          Albany Hospital   cylinder_g      2
# 99   1/12/2022                          Warren Hospital   cylinder_g      2
# 100  1/12/2022                       Geraldton Hospital   cylinder_g      2
#
# ...

# %%
cylinder_list = ['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g', 'total']

for index, row in metro_df.iterrows():
    cylinder = row['cylinder']
    for item in cylinder_list:
        if item == cylinder:
            metro_df.loc[index, item] = row['units']
        else:
            metro_df.loc[index, item] = 0
    
metro_df
# Out:
#           date                                     name     cylinder  units  \
# 0    1/01/2022                         Bentley Hospital   cylinder_g      2
# 1    1/01/2022  King Edward Memorial Hospital For Women   cylinder_g      8
# 2    1/01/2022     Armadale-Kelmscott Memorial Hospital   cylinder_c      1
# 3    1/01/2022              Rockingham General Hospital   cylinder_c      1
# 4    1/01/2022                     Royal Perth Hospital  cylinder_f8      1
# ..         ...                                      ...          ...    ...
# 96   1/11/2022                          Albany Hospital   cylinder_g      2
# 97   1/11/2022                          Warren Hospital   cylinder_g      2
# 98   1/12/2022                          Albany Hospital   cylinder_g      2
# 99   1/12/2022                          Warren Hospital   cylinder_g      2
# 100  1/12/2022                       Geraldton Hospital   cylinder_g      2
#
# ...

# %%
merged_data = pd.DataFrame(columns={'date', 'name', 'cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g'})

purchase_dates = metro_df['date'].unique()
hospital_list = metro_df['name'].unique()
cylinder_list = ['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g']

for date in purchase_dates:
    for hospital in hospital_list:
        # did the current hospital have a purchase on this date         
        current_hosp = metro_df[metro_df['name'] == hospital]
        matched_purchase_dates = current_hosp[current_hosp['date'] == date]
        
        # if so, iterate through the purchases on this date and add to merged df        
        if (len(matched_purchase_dates) != 0):
                      
            # temp df to append to the final merged data
            new_row = pd.DataFrame(columns={'date', 'name', 'cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g'})
            new_row.loc[0, 'date'] = date
            new_row.loc[0, 'name'] = hospital
            
            # add each cylinder purchase to the new row and append
            for index, row in matched_purchase_dates.iterrows():
                for item in cylinder_list:
                    
                    if row[item] != 0:
                        new_row[item][0] = row[item]

                    elif (row[item] == 0) & (pd.isnull(new_row[item][0]) == True):
                        new_row.loc[0, item] = 0
                    
            merged_data = merged_data.append(new_row).reset_index(drop=True)
                        
merged_data = merged_data[['date', 'name', 'cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g']]
merged_data
# Out:
#          date                                     name cylinder_c cylinder_d  \
# 0   1/01/2022                         Bentley Hospital          0          0
# 1   1/01/2022  King Edward Memorial Hospital For Women          0          0
# 2   1/01/2022     Armadale-Kelmscott Memorial Hospital          1          0
# 3   1/01/2022              Rockingham General Hospital          1          0
# 4   1/01/2022                     Royal Perth Hospital          0          0
# ..        ...                                      ...        ...        ...
# 87  1/12/2022                    Osborne Park Hospital          0          0
# 88  1/12/2022                   Fiona Stanley Hospital          0          0
# 89  1/12/2022                          Warren Hospital          0          0
# 90  1/12/2022                          Albany Hospital          0          0
# 91  1/12/2022                       Geraldton Hospital          0          0
#
# ...

# %%
# Add total column
final_df = merged_data.copy()
cylinder_list = ['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g']

# Helper function to return total 
def total_calculator(row):
    total = 0
    amount = 0
    
    for cylinder in cylinder_list:
        if cylinder == 'cylinder_c':
            amount = row[cylinder] * 1.75
        elif cylinder == 'cylinder_d':
            amount = row[cylinder] * 6.6
        elif cylinder == 'cylinder_e':
            amount = row[cylinder] * 16.8
        elif cylinder == 'cylinder_f8':
            amount = row[cylinder] * 233
        elif cylinder == 'cylinder_f9':
            amount = row[cylinder] * 223
        elif cylinder == 'cylinder_g':
            amount = row[cylinder] * 36.6
            
        total += amount
    
    return(float(total))

for row in range (0, len(final_df)):
    total = total_calculator(final_df.iloc[[row]])
    final_df.loc[row, 'total'] = total
    
final_df
# Out:
#          date                                     name cylinder_c cylinder_d  \
# 0   1/01/2022                         Bentley Hospital          0          0
# 1   1/01/2022  King Edward Memorial Hospital For Women          0          0
# 2   1/01/2022     Armadale-Kelmscott Memorial Hospital          1          0
# 3   1/01/2022              Rockingham General Hospital          1          0
# 4   1/01/2022                     Royal Perth Hospital          0          0
# ..        ...                                      ...        ...        ...
# 87  1/12/2022                    Osborne Park Hospital          0          0
# 88  1/12/2022                   Fiona Stanley Hospital          0          0
# 89  1/12/2022                          Warren Hospital          0          0
# 90  1/12/2022                          Albany Hospital          0          0
# 91  1/12/2022                       Geraldton Hospital          0          0
#
# ...

# %%
final_df = final_df.round({'total': 1})
final_df
# Out:
#          date                                     name cylinder_c cylinder_d  \
# 0   1/01/2022                         Bentley Hospital          0          0
# 1   1/01/2022  King Edward Memorial Hospital For Women          0          0
# 2   1/01/2022     Armadale-Kelmscott Memorial Hospital          1          0
# 3   1/01/2022              Rockingham General Hospital          1          0
# 4   1/01/2022                     Royal Perth Hospital          0          0
# ..        ...                                      ...        ...        ...
# 87  1/12/2022                    Osborne Park Hospital          0          0
# 88  1/12/2022                   Fiona Stanley Hospital          0          0
# 89  1/12/2022                          Warren Hospital          0          0
# 90  1/12/2022                          Albany Hospital          0          0
# 91  1/12/2022                       Geraldton Hospital          0          0
#
# ...

# %%
outname = "2022_data.csv"

# Write to CSV
final_df.to_csv(outname, index=False, encoding='utf-8')

# %%
final_df = pd.read_csv("2022_data.csv")
final_df
# Out:
#          date                                     name  cylinder_c  \
# 0   1/01/2022                         Bentley Hospital           0
# 1   1/01/2022  King Edward Memorial Hospital For Women           0
# 2   1/01/2022     Armadale-Kelmscott Memorial Hospital           1
# 3   1/01/2022              Rockingham General Hospital           1
# 4   1/01/2022                     Royal Perth Hospital           0
# ..        ...                                      ...         ...
# 87  1/12/2022                    Osborne Park Hospital           0
# 88  1/12/2022                   Fiona Stanley Hospital           0
# 89  1/12/2022                          Warren Hospital           0
# 90  1/12/2022                          Albany Hospital           0
# 91  1/12/2022                       Geraldton Hospital           0
#
#     cylinder_d  cylinder_e  cylinder_f8  cylinder_f9  cylinder_g  total
# 0            0           0            0            0           2   73.2
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

final_df.to_sql("purchases", engine, if_exists="append", index=False)

# %%
from sqlalchemy.engine.create import create_engine

engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

result = pd.read_sql_table(
	"purchases",  # table name
	con=engine
)

result
# Out:
#      purchase_id                                     name  cylinder_c  \
# 0              1     Armadale-Kelmscott Memorial Hospital           0
# 1              2                         Bentley Hospital           0
# 2              3                   Fiona Stanley Hospital           0
# 3              4    Kalamunda District Community Hospital           0
# 4              5                    Osborne Park Hospital           0
# ..           ...                                      ...         ...
# 247          248            Sir Charles Gairdner Hospital           1
# 248          249  King Edward Memorial Hospital For Women           0
# 249          250                   Fiona Stanley Hospital           0
# 250          251                    Osborne Park Hospital           0
# 251          252              Rockingham General Hospital           0
#
#      cylinder_d  cylinder_e  cylinder_f8  cylinder_f9  cylinder_g       date  \
# ...

# %% [markdown]
# # Regional Data

# %%
regional_df = pd.read_csv("regional_clean.csv")

regional_df.rename(columns={"hospital":"name"}, inplace=True)
regional_df
# Out:
#           date                     name    cylinder  units
# 0    1/01/2017       Busselton Hospital  cylinder_g      2
# 1    1/01/2017           Derby Hospital  cylinder_e      2
# 2    1/01/2017          Albany Hospital  cylinder_d      1
# 3    1/01/2017          Albany Hospital  cylinder_g      2
# 4    1/01/2017       Kununurra Hospital  cylinder_e      2
# ..         ...                      ...         ...    ...
# 250  1/12/2021       Geraldton Hospital  cylinder_g      2
# 251  1/12/2021  Margaret River Hospital  cylinder_g      1
# 252  1/12/2021          Warren Hospital  cylinder_g      4
# 253  1/12/2021       Kununurra Hospital  cylinder_c      2
# 254  1/12/2021       Kununurra Hospital  cylinder_e      2
#
# [255 rows x 4 columns]

# %%
regional_df[['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 
          'cylinder_g', 'total']] = ["", "", "", "", "", "", ""]
regional_df
# Out:
#           date                     name    cylinder  units cylinder_c  \
# 0    1/01/2017       Busselton Hospital  cylinder_g      2
# 1    1/01/2017           Derby Hospital  cylinder_e      2
# 2    1/01/2017          Albany Hospital  cylinder_d      1
# 3    1/01/2017          Albany Hospital  cylinder_g      2
# 4    1/01/2017       Kununurra Hospital  cylinder_e      2
# ..         ...                      ...         ...    ...        ...
# 250  1/12/2021       Geraldton Hospital  cylinder_g      2
# 251  1/12/2021  Margaret River Hospital  cylinder_g      1
# 252  1/12/2021          Warren Hospital  cylinder_g      4
# 253  1/12/2021       Kununurra Hospital  cylinder_c      2
# 254  1/12/2021       Kununurra Hospital  cylinder_e      2
#
#     cylinder_d cylinder_e cylinder_f8 cylinder_f9 cylinder_g total
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...         ...         ...        ...   ...
# 250
# 251
# 252
# 253
# 254
#
# [255 rows x 11 columns]

# %%
cylinder_list = ['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g', 'total']

for index, row in regional_df.iterrows():
    cylinder = row['cylinder']
    for item in cylinder_list:
        if item == cylinder:
            regional_df.loc[index, item] = row['units']
        else:
            regional_df.loc[index, item] = 0
    
regional_df
# Out:
#           date                     name    cylinder  units cylinder_c  \
# 0    1/01/2017       Busselton Hospital  cylinder_g      2          0
# 1    1/01/2017           Derby Hospital  cylinder_e      2          0
# 2    1/01/2017          Albany Hospital  cylinder_d      1          0
# 3    1/01/2017          Albany Hospital  cylinder_g      2          0
# 4    1/01/2017       Kununurra Hospital  cylinder_e      2          0
# ..         ...                      ...         ...    ...        ...
# 250  1/12/2021       Geraldton Hospital  cylinder_g      2          0
# 251  1/12/2021  Margaret River Hospital  cylinder_g      1          0
# 252  1/12/2021          Warren Hospital  cylinder_g      4          0
# 253  1/12/2021       Kununurra Hospital  cylinder_c      2          2
# 254  1/12/2021       Kununurra Hospital  cylinder_e      2          0
#
#     cylinder_d cylinder_e cylinder_f8 cylinder_f9 cylinder_g total
# ...

# %%
merged_data = pd.DataFrame(columns={'date', 'name', 'cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g'})

purchase_dates = regional_df['date'].unique()
hospital_list = regional_df['name'].unique()
cylinder_list = ['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g']

for date in purchase_dates:
    for hospital in hospital_list:
        # did the current hospital have a purchase on this date         
        current_hosp = regional_df[regional_df['name'] == hospital]
        matched_purchase_dates = current_hosp[current_hosp['date'] == date]
        
        # if so, iterate through the purchases on this date and add to merged df        
        if (len(matched_purchase_dates) != 0):
                      
            # temp df to append to the final merged data
            new_row = pd.DataFrame(columns={'date', 'name', 'cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g'})
            new_row.loc[0, 'date'] = date
            new_row.loc[0, 'name'] = hospital
            
            # add each cylinder purchase to the new row and append
            for index, row in matched_purchase_dates.iterrows():
                for item in cylinder_list:
                    
                    if row[item] != 0:
                        new_row[item][0] = row[item]

                    elif (row[item] == 0) & (pd.isnull(new_row[item][0]) == True):
                        new_row.loc[0, item] = 0
                    
            merged_data = merged_data.append(new_row).reset_index(drop=True)
                        
merged_data = merged_data[['date', 'name', 'cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g']]
merged_data
# Out:
#           date                     name cylinder_c cylinder_d cylinder_e  \
# 0    1/01/2017       Busselton Hospital          0          0          0
# 1    1/01/2017           Derby Hospital          0          0          2
# 2    1/01/2017          Albany Hospital          0          1          0
# 3    1/01/2017       Kununurra Hospital          0          0          2
# 4    1/01/2018          Albany Hospital          0          0          0
# ..         ...                      ...        ...        ...        ...
# 228  1/12/2021          Albany Hospital          0          0          0
# 229  1/12/2021       Kununurra Hospital          2          0          2
# 230  1/12/2021       Geraldton Hospital          0          0          0
# 231  1/12/2021          Warren Hospital          0          0          0
# 232  1/12/2021  Margaret River Hospital          0          0          0
#
#     cylinder_f8 cylinder_f9 cylinder_g
# 0             0           0          2
# ...

# %%
# Add total column
final_df = merged_data.copy()
cylinder_list = ['cylinder_c', 'cylinder_d', 'cylinder_e', 'cylinder_f8', 'cylinder_f9', 'cylinder_g']

# Helper function to return total 
def total_calculator(row):
    total = 0
    amount = 0
    
    for cylinder in cylinder_list:
        if cylinder == 'cylinder_c':
            amount = row[cylinder] * 1.75
        elif cylinder == 'cylinder_d':
            amount = row[cylinder] * 6.6
        elif cylinder == 'cylinder_e':
            amount = row[cylinder] * 16.8
        elif cylinder == 'cylinder_f8':
            amount = row[cylinder] * 233
        elif cylinder == 'cylinder_f9':
            amount = row[cylinder] * 223
        elif cylinder == 'cylinder_g':
            amount = row[cylinder] * 36.6
            
        total += amount
    
    return(float(total))

for row in range (0, len(final_df)):
    total = total_calculator(final_df.iloc[[row]])
    final_df.loc[row, 'total'] = total
    
final_df
# Out:
#           date                     name cylinder_c cylinder_d cylinder_e  \
# 0    1/01/2017       Busselton Hospital          0          0          0
# 1    1/01/2017           Derby Hospital          0          0          2
# 2    1/01/2017          Albany Hospital          0          1          0
# 3    1/01/2017       Kununurra Hospital          0          0          2
# 4    1/01/2018          Albany Hospital          0          0          0
# ..         ...                      ...        ...        ...        ...
# 228  1/12/2021          Albany Hospital          0          0          0
# 229  1/12/2021       Kununurra Hospital          2          0          2
# 230  1/12/2021       Geraldton Hospital          0          0          0
# 231  1/12/2021          Warren Hospital          0          0          0
# 232  1/12/2021  Margaret River Hospital          0          0          0
#
#     cylinder_f8 cylinder_f9 cylinder_g  total
# ...

# %%
final_df = final_df.round({'total': 1})
final_df
# Out:
#           date                     name cylinder_c cylinder_d cylinder_e  \
# 0    1/01/2017       Busselton Hospital          0          0          0
# 1    1/01/2017           Derby Hospital          0          0          2
# 2    1/01/2017          Albany Hospital          0          1          0
# 3    1/01/2017       Kununurra Hospital          0          0          2
# 4    1/01/2018          Albany Hospital          0          0          0
# ..         ...                      ...        ...        ...        ...
# 228  1/12/2021          Albany Hospital          0          0          0
# 229  1/12/2021       Kununurra Hospital          2          0          2
# 230  1/12/2021       Geraldton Hospital          0          0          0
# 231  1/12/2021          Warren Hospital          0          0          0
# 232  1/12/2021  Margaret River Hospital          0          0          0
#
#     cylinder_f8 cylinder_f9 cylinder_g  total
# ...

# %%
outname = "final_regional_data.csv"

# Write to CSV
final_df.to_csv(outname, index=False, encoding='utf-8')

# %%
final_df = pd.read_csv("purchases.csv")
final_df
# Out:
#           date                                   name  cylinder_c  cylinder_d  \
# 0    1/01/2017   Armadale-Kelmscott Memorial Hospital           0           0
# 1    1/01/2017                       Bentley Hospital           0           0
# 2    1/01/2017                 Fiona Stanley Hospital           0           0
# 3    1/01/2017  Kalamunda District Community Hospital           0           0
# 4    1/01/2017                  Osborne Park Hospital           0           0
# ..         ...                                    ...         ...         ...
# 572  1/12/2022                  Osborne Park Hospital           0           0
# 573  1/12/2022                 Fiona Stanley Hospital           0           0
# 574  1/12/2022                        Warren Hospital           0           0
# 575  1/12/2022                        Albany Hospital           0           0
# 576  1/12/2022                     Geraldton Hospital           0           0
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

final_df.to_sql("purchases", engine, if_exists="append", index=False)

# %%
from sqlalchemy.engine.create import create_engine

engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

result = pd.read_sql_table(
	"purchases",  # table name
	con=engine
)

result
# Out:
#      purchase_id                                   name  cylinder_c  \
# 0              1   Armadale-Kelmscott Memorial Hospital           0
# 1              2                       Bentley Hospital           0
# 2              3                 Fiona Stanley Hospital           0
# 3              4  Kalamunda District Community Hospital           0
# 4              5                  Osborne Park Hospital           0
# ..           ...                                    ...         ...
# 480          481                        Albany Hospital           0
# 481          482                     Kununurra Hospital           2
# 482          483                     Geraldton Hospital           0
# 483          484                        Warren Hospital           0
# 484          485                Margaret River Hospital           0
#
#      cylinder_d  cylinder_e  cylinder_f8  cylinder_f9  cylinder_g       date  \
# ...

# %% [markdown]
# # Combined Purchase Data

# %%
metro_data = pd.read_csv('final_metro_data.csv')
regional_data = pd.read_csv("final_regional_data.csv")

all_purchases = pd.concat([metro_data,regional_data],axis=0,join='inner')
all_purchases.reset_index(drop=True, inplace=True)

# Write to CSV
outname = "purchases.csv"
all_purchases.to_csv(outname, index=False, encoding='utf-8')

all_purchases
# Out:
#           date                                   name  cylinder_c  cylinder_d  \
# 0    1/01/2017   Armadale-Kelmscott Memorial Hospital           0           0
# 1    1/01/2017                       Bentley Hospital           0           0
# 2    1/01/2017                 Fiona Stanley Hospital           0           0
# 3    1/01/2017  Kalamunda District Community Hospital           0           0
# 4    1/01/2017                  Osborne Park Hospital           0           0
# ..         ...                                    ...         ...         ...
# 480  1/12/2021                        Albany Hospital           0           0
# 481  1/12/2021                     Kununurra Hospital           2           0
# 482  1/12/2021                     Geraldton Hospital           0           0
# 483  1/12/2021                        Warren Hospital           0           0
# 484  1/12/2021                Margaret River Hospital           0           0
#
# ...

# %% [markdown]
# # Hospital Data

# %%
geo_data = pd.read_json("../static/data/Health_Hospitals_WA.geojson")

def hosp_finder(json_object, name):
    hosp_data = {"address":"", "suburb":"", "postcode":"", "lat":0, "long":0}
    for item in json_object['features']:
        if item['properties']['establishment_name'] == name:
            hosp_data = {
                         "name": name,
                         "address": item['properties']['address'],
                         "suburb": item['properties']['suburb'],
                         "postcode": item['properties']['postcode'],
                         "lat": item['geometry']['coordinates'][1],
                         "long": item['geometry']['coordinates'][0]
                        }

    return hosp_data

# %%
hosp_table = pd.DataFrame(columns=('id', 'name', 'address', 'suburb', 'postcode', 'state', 'country', 'lat',
                                   'long', 'hosp_type', 'region', 'cases_adult', 'cases_obs', 'cases_paed', 'cases_burns',
                                   'supplier', 'maintenance', 'diagram', 'outlets'))

hospital_names = all_purchases['name'].unique()

for hosp in hospital_names:
    hosp_data = hosp_finder(geo_data, hosp)
    new_row = {
               'id':len(hosp_table), 'name':hosp_data['name'], 'address':hosp_data['address'],
               'suburb':hosp_data['suburb'], 'postcode':hosp_data['postcode'], 'state':'WA',
               'country':'Australia', 'lat':hosp_data['lat'], 'long':hosp_data['long'], 'hosp_type':'',
               'region':'', 'cases_adult':0, 'cases_obs':0, 'cases_paed':0, 'cases_burns':0,
               'supplier':'', 'maintenance':'', 'diagram':'', 'outlets':''
              }
    hosp_table = hosp_table.append(new_row, ignore_index=True)
    
hosp_table
# Out:
#     id                                     name  \
# 0    0     Armadale-Kelmscott Memorial Hospital
# 1    1                         Bentley Hospital
# 2    2                   Fiona Stanley Hospital
# 3    3    Kalamunda District Community Hospital
# 4    4                    Osborne Park Hospital
# 5    5              Rockingham General Hospital
# 6    6            Sir Charles Gairdner Hospital
# 7    7  King Edward Memorial Hospital For Women
# 8    8                     Royal Perth Hospital
# 9    9                Perth Children's Hospital
# 10  10                       Busselton Hospital
# 11  11                           Derby Hospital
# 12  12                          Albany Hospital
# 13  13                       Kununurra Hospital
# 14  14                       Katanning Hospital
# 15  15                   Karratha Health Campus
# 16  16                       Geraldton Hospital
# 17  17                        Merredin Hospital
# ...

# %%
# Write to CSV
outname = "hospitals.csv"
hosp_table.to_csv(outname, index=False, encoding='utf-8')

# %%
hospitals = pd.read_csv("hospitals.csv")
hospitals.head(7)
# Out:
#    id                                   name                address  \
# 0   0   Armadale-Kelmscott Memorial Hospital    3056 Albany Highway
# 1   1                       Bentley Hospital        33 Mills Street
# 2   2                 Fiona Stanley Hospital  11 Robin Warren Drive
# 3   3  Kalamunda District Community Hospital       Elizabeth Street
# 4   4                  Osborne Park Hospital          Osborne Place
# 5   5            Rockingham General Hospital          Elanora Drive
# 6   6          Sir Charles Gairdner Hospital        Hospital Avenue
#
#          suburb  postcode state    country        lat        long  hosp_type  \
# 0  MOUNT NASURA      6112    WA  Australia -32.132859  116.020882        NaN
# 1       BENTLEY      6102    WA  Australia -32.005523  115.927575        NaN
# 2       MURDOCH      6150    WA  Australia -32.070171  115.846403        NaN
# 3     KALAMUNDA      6076    WA  Australia -31.966697  116.060629        NaN
# ...

# %%
hospitals = hospitals[hospitals['name']=='Sir Charles Gairdner Hospital']
hospitals
# Out:
#    id                           name          address    suburb  postcode  \
# 6   6  Sir Charles Gairdner Hospital  Hospital Avenue  NEDLANDS      6009
#
#   state    country        lat        long  hosp_type region network  \
# 6    WA  Australia -31.967909  115.814946        NaN  metro    NMHS
#
#    cases_adult  cases_obs  cases_paed  cases_burns  supplier  maintenance  \
# 6            0          0           0            0       NaN          NaN
#
#    diagram  outlets
# 6      NaN      NaN

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

hospitals.to_sql("hospitals", engine, if_exists="append", index=False)

# %%
from sqlalchemy.engine.create import create_engine

engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

result = pd.read_sql_table(
	"hospitals",  # table name
	con=engine
)

result
# Out:
#     id                                     name  \
# 0    0     Armadale-Kelmscott Memorial Hospital
# 1    1                         Bentley Hospital
# 2    2                   Fiona Stanley Hospital
# 3    3    Kalamunda District Community Hospital
# 4    4                    Osborne Park Hospital
# 5    5              Rockingham General Hospital
# 6    7  King Edward Memorial Hospital For Women
# 7    8                     Royal Perth Hospital
# 8    9                Perth Children's Hospital
# 9   10                       Busselton Hospital
# 10  11                           Derby Hospital
# 11  12                          Albany Hospital
# 12  13                       Kununurra Hospital
# 13  14                       Katanning Hospital
# 14  15                   Karratha Health Campus
# 15  16                       Geraldton Hospital
# 16  17                        Merredin Hospital
# 17  18                         Mullewa Hospital
# ...

# %% [markdown]
# # Manifold Data

# %%
manifold_table = pd.DataFrame(columns=('manifold_id', 'name', 'cylinder_f8', 'cylinder_f9', 'cylinder_g', 'date'))

hospitals = pd.read_csv("hospitals.csv")
hospital_names = hospitals['name'].unique()

for hosp in hospital_names:
    new_row = {
               'manifold_id':len(manifold_table), 'name':hosp, 
               'cylinder_f8':0, 'cylinder_f9':0, 'cylinder_g':0, 'date':''
              }
    manifold_table = manifold_table.append(new_row, ignore_index=True)
    
manifold_table.head()
# Out:
#   manifold_id                                   name cylinder_f8 cylinder_f9  \
# 0           0   Armadale-Kelmscott Memorial Hospital           0           0
# 1           1                       Bentley Hospital           0           0
# 2           2                 Fiona Stanley Hospital           0           0
# 3           3  Kalamunda District Community Hospital           0           0
# 4           4                  Osborne Park Hospital           0           0
#
#   cylinder_g date
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Write to CSV
outname = "manifolds.csv"
manifold_table.to_csv(outname, index=False, encoding='utf-8')

# %%
manifolds = pd.read_csv("manifolds.csv")
manifolds.head()
# Out:
#    manifold_id                                   name  cylinder_f8  \
# 0            0   Armadale-Kelmscott Memorial Hospital            0
# 1            1                       Bentley Hospital            0
# 2            2                 Fiona Stanley Hospital            0
# 3            3  Kalamunda District Community Hospital            0
# 4            4                  Osborne Park Hospital            0
#
#    cylinder_f9  cylinder_g  date
# 0            0           0   NaN
# 1            0           0   NaN
# 2            0           0   NaN
# 3            0           0   NaN
# 4            0           0   NaN

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://nitrous_user:jZce01ie7vIU1brnuzFZOESh4IVczwMo@dpg-cho5epvdvk4rn2t4lun0-a.singapore-postgres.render.com/nitrous')

manifolds.to_sql("manifolds", engine, if_exists="append", index=False)
